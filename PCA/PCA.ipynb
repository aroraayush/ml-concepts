# %%
import pandas as pd

# %%
df = pd.read_csv("credit_fraud_class.csv")

# %%
df.head(10)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  1.176563  0.323798  0.536927  1.047002 -0.368652 -0.728586  0.084678
# 1  0.681109 -3.934776 -3.801827 -1.147468 -0.735540 -0.501097  1.038865
# 2  1.140729  0.453484  0.247010  2.383132  0.343287  0.432804  0.093380
# 3 -1.107073 -3.298902 -0.184092 -1.795744  2.137564 -1.684992 -2.015606
# 4 -0.314818  0.866839 -0.124577 -0.627638  2.651762  3.428128  0.194637
# 5 -0.713266  0.869132  0.330114  0.902275  0.520836 -0.537036  0.301955
# 6  1.219060 -0.207708  0.782809  0.271655 -0.456658  0.414201 -0.675133
# 7  0.683918  0.329216 -1.693025 -1.123644  2.662177  3.563731 -0.309291
# 8 -1.127820  1.461342  0.526673 -0.158998  0.353158 -1.539196  0.727383
# 9 -1.757794  0.821894  2.529482 -0.328198 -0.902062  0.739803 -0.119755
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0 -0.069246 -0.266389  0.155315  ... -0.109627 -0.341365  0.057845  0.499180
# ...

# %% [markdown]
# ### Looking at the Distribution of the data

# %%
df.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  21693.000000  21693.000000  21693.000000  21693.000000  21693.000000
# mean      -0.032403      0.047565     -0.091623      0.057805     -0.033983
# std        2.106997      1.690911      1.870289      1.540329      1.530508
# min      -41.928738    -40.803981    -31.103685     -4.848504    -32.092129
# 25%       -0.929371     -0.592921     -0.962975     -0.850069     -0.698296
# 50%        0.007545      0.075215      0.176534     -0.012868     -0.063948
# 75%        1.315678      0.819749      1.020809      0.772388      0.615287
# max        2.451888     21.467203      4.069865     12.114672     29.162172
#
#                  V6            V7            V8            V9           V10  \
# count  21693.000000  21693.000000  21693.000000  21693.000000  21693.000000
# mean      -0.023207     -0.074203      0.002096     -0.044311     -0.091073
# ...

# %% [markdown]
# ### Let us see the correlation between all values

# %%
df.corr()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# V1      1.000000 -0.146151  0.215212 -0.128453  0.170542  0.034279  0.255483
# V2     -0.146151  1.000000 -0.208005  0.145315 -0.141299 -0.044490 -0.204274
# V3      0.215212 -0.208005  1.000000 -0.215700  0.232629  0.069899  0.353663
# V4     -0.128453  0.145315 -0.215700  1.000000 -0.133877 -0.054986 -0.211180
# V5      0.170542 -0.141299  0.232629 -0.133877  1.000000  0.038777  0.252781
# V6      0.034279 -0.044490  0.069899 -0.054986  0.038777  1.000000  0.061177
# V7      0.255483 -0.204274  0.353663 -0.211180  0.252781  0.061177  1.000000
# V8     -0.005986 -0.029483 -0.032595  0.026285 -0.044492 -0.074040  0.052792
# V9      0.148964 -0.138545  0.196321 -0.129070  0.132767  0.027948  0.200578
# V10     0.256063 -0.242308  0.367115 -0.221332  0.246547  0.079684  0.382375
# V11    -0.151016  0.136008 -0.240823  0.175382 -0.148047 -0.066176 -0.235008
# ...

# %% [markdown]
# ### Checking for null values

# %%
df.isna().sum()
# Out:
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.count()
# Out:
# V1        21693
# V2        21693
# V3        21693
# V4        21693
# V5        21693
# V6        21693
# V7        21693
# V8        21693
# V9        21693
# V10       21693
# V11       21693
# V12       21693
# V13       21693
# V14       21693
# V15       21693
# V16       21693
# V17       21693
# V18       21693
# V19       21693
# V20       21693
# V21       21693
# V22       21693
# V23       21693
# V24       21693
# V25       21693
# V26       21693
# V27       21693
# V28       21693
# Amount    21693
# Class     21693
# dtype: int64

# %% [markdown]
# ### There are 21,693 records with no null values

# %% [markdown]
# ### Let us obtain the correlation between the "Class" variable and other records

# %% [markdown]
# #### Splitting the input attributes

# %%
x_df = df.iloc[:,:-1]
x_df
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# 0      1.176563  0.323798  0.536927  1.047002 -0.368652 -0.728586  0.084678
# 1      0.681109 -3.934776 -3.801827 -1.147468 -0.735540 -0.501097  1.038865
# 2      1.140729  0.453484  0.247010  2.383132  0.343287  0.432804  0.093380
# 3     -1.107073 -3.298902 -0.184092 -1.795744  2.137564 -1.684992 -2.015606
# 4     -0.314818  0.866839 -0.124577 -0.627638  2.651762  3.428128  0.194637
# ...         ...       ...       ...       ...       ...       ...       ...
# 21688 -3.959670  3.297819 -1.079436 -2.290106 -1.405133  2.452586 -4.649235
# 21689 -1.066503  0.539240  0.735343 -0.506800  0.843980 -1.047877  1.141302
# 21690 -2.175162 -0.441681  1.883137 -0.267440  1.056972  0.136404  0.113595
# 21691  0.031406  0.694817  0.083233 -0.797912  0.564318 -0.560787  0.805901
# 21692 -0.312369  0.944738  1.430605  0.627951  0.317725 -0.180406  0.793108
#
# ...

# %%
y_df = df.iloc[:,-1:]["Class"]
y_df
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 21688    0
# 21689    0
# 21690    0
# 21691    0
# 21692    0
# Name: Class, Length: 21693, dtype: int64

# %% [markdown]
# #### Obtaining the correlation of class and other variables

# %%
corr_df = x_df.corrwith(y_df, axis = 0)
corr_df = corr_df.to_frame()
corr_df.columns = ['correlation']
corr_df.head(10)
# Out:
#      correlation
# V1     -0.266090
# V2      0.261974
# V3     -0.455432
# V4      0.367881
# V5     -0.240984
# V6     -0.128316
# V7     -0.423161
# V8      0.031553
# V9     -0.276200
# V10    -0.517501

# %% [markdown]
# ### Let us look what all columns/features correlate with our target variable

# %%
sorted_df = corr_df.reindex(df3.b.abs().sort_values().index)
sorted_df
# Out:
#         correlation
# V22        0.001778
# V23        0.002636
# V25        0.005942
# V15       -0.008723
# V26        0.012615
# V13       -0.013606
# Amount     0.016129
# V24       -0.022063
# V8         0.031553
# V28        0.051853
# V27        0.061525
# V20        0.061622
# V19        0.102538
# V21        0.112028
# V6        -0.128316
# V5        -0.240984
# V2         0.261974
# V1        -0.266090
# V9        -0.276200
# V18       -0.291351
# V4         0.367881
# V11        0.415576
# V7        -0.423161
# V3        -0.455432
# V16       -0.469196
# V10       -0.517501
# V12       -0.569415
# V17       -0.575181
# V14       -0.646226

# %% [markdown]
# ### Max correlation

# %%
max(sorted_df['correlation'])
# Out:
# 0.4155759499905006

# %% [markdown]
# ### Check if our target variable has more than 1 value or not

# %%
y_df.unique()
# Out:
# array([0, 1])

# %%
x_df.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
#       dtype='object')

# %% [markdown]
# ## Scaling the data with StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
x = x_df.values
x
# Out:
# array([[ 1.17656255e+00,  3.23797640e-01,  5.36927047e-01, ...,
#          1.54721350e-02,  1.80650390e-02,  4.67000000e+00],
#        [ 6.81109486e-01, -3.93477632e+00, -3.80182745e+00, ...,
#         -2.56272932e-01,  5.65009040e-02,  9.12000000e+02],
#        [ 1.14072868e+00,  4.53483633e-01,  2.47010003e-01, ...,
#         -1.21148190e-02, -5.94502500e-03,  1.00000000e+00],
#        ...,
#        [-2.17516167e+00, -4.41681440e-01,  1.88313689e+00, ...,
#          4.33089084e-01, -1.50290873e-01,  1.31100000e+02],
#        [ 3.14062620e-02,  6.94816666e-01,  8.32325030e-02, ...,
#          2.32845962e-01,  7.94200570e-02,  4.49000000e+00],
#        [-3.12369468e-01,  9.44737713e-01,  1.43060545e+00, ...,
#          2.32375299e-01, -2.35628650e-02,  1.49000000e+01]])

# %%
# Converting the object type to float for precesion
x = x.astype(float)
x = StandardScaler().fit_transform(x)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 29)
principal_components = pca.fit_transform(x)
principal_components
# Out:
# array([[-0.17354985, -0.53127991, -0.22344202, ..., -0.20026214,
#          0.64755685,  0.01978616],
#        [-0.12719643,  4.43394088,  0.19848227, ..., -0.50704762,
#         -0.32374059, -0.13125135],
#        [-0.11301882, -0.50225599, -0.07068779, ..., -0.26074516,
#          0.39169625,  0.01989095],
#        ...,
#        [-0.50365588,  0.11892763, -0.16339087, ...,  0.75351624,
#          0.44326072, -0.28048114],
#        [-0.34069114, -0.55016344, -0.36392308, ..., -0.49968829,
#          0.65252516,  0.06623096],
#        [-0.22455373, -0.34305179, -0.09086771, ..., -0.3559522 ,
#          0.58407365,  0.09845751]])

# %%
princ_df = pd.DataFrame(data = principal_components)
princ_df
# Out:
#              0         1          2          3         4         5         6   \
# 0     -0.173550 -0.531280  -0.223442  -0.154166  0.382044 -0.463292 -0.227322
# 1     -0.127196  4.433941   0.198482  -0.765319 -0.289109 -1.116150 -0.165568
# 2     -0.113019 -0.502256  -0.070688   0.028466 -0.578638 -1.489014  0.977746
# 3     -0.457057  0.090379  -0.086674   0.024973 -0.167532  1.058568  0.246321
# 4     -0.409861 -0.147872  -0.397855  -0.044970 -0.505702  2.119551 -1.325856
# ...         ...       ...        ...        ...       ...       ...       ...
# 21688  0.342318 -1.084908 -10.127327  13.292037  1.357699  1.214298  0.128663
# 21689 -0.025181 -0.238743  -0.373793  -0.353012 -0.348734 -1.337261 -0.155653
# 21690 -0.503656  0.118928  -0.163391  -0.844175 -0.139893 -0.964336  0.981782
# 21691 -0.340691 -0.550163  -0.363923   0.096276 -0.443776 -0.106107 -0.369089
# 21692 -0.224554 -0.343052  -0.090868  -0.666287 -0.409957  0.625482 -0.698838
#
# ...

# %%
# Explained Variance Ratio

# Ref: https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html

ex_var_rat = pca.explained_variance_ratio_
ex_var_rat
# Out:
# array([0.15669115, 0.06040375, 0.04344908, 0.04094522, 0.03777904,
#        0.03566089, 0.03541377, 0.03507235, 0.03448774, 0.03436712,
#        0.03373362, 0.03321766, 0.03311287, 0.03211695, 0.0312376 ,
#        0.03048095, 0.03003149, 0.02972773, 0.02847356, 0.02791445,
#        0.02710221, 0.02542333, 0.02372559, 0.0233596 , 0.02118158,
#        0.01957706, 0.01861141, 0.01496339, 0.00173881])

# %%
for i in ex_var_rat:
    print('{:0.5f}'.format(i))
# Out:
# 0.15669
# 0.06040
# 0.04345
# 0.04095
# 0.03778
# 0.03566
# 0.03541
# 0.03507
# 0.03449
# 0.03437
# 0.03373
# 0.03322
# 0.03311
# 0.03212
# 0.03124
# 0.03048
# 0.03003
# 0.02973
# 0.02847
# 0.02791
# 0.02710
# 0.02542
# 0.02373
# 0.02336
# 0.02118
# 0.01958
# 0.01861
# 0.01496
# 0.00174

# %% [markdown]
# ### Visualizing the Explained Variance Ratio

# %%
import matplotlib.pyplot as plt 

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Total Explained Variance');

# %% [markdown]
# #### As per the figure above, the optimal number of components for 90% variance is 22.

# %% [markdown]
# ### Re-fitting input(X) into PCA specifying the optimal number of components identified.

# %%
pca2 = PCA(n_components = 22)
principal_components2 = pca2.fit_transform(x)
principal_df2 = pd.DataFrame(data = principal_components2)
evr2 = pca2.explained_variance_ratio_
evr2
# Out:
# array([0.15669115, 0.06040375, 0.04344908, 0.04094522, 0.03777904,
#        0.03566089, 0.03541377, 0.03507235, 0.03448774, 0.03436712,
#        0.03373362, 0.03321766, 0.03311287, 0.03211695, 0.0312376 ,
#        0.03048095, 0.03003149, 0.02972773, 0.02847356, 0.02791445,
#        0.02710221, 0.02542333])

# %%
for i in evr2:
    print('{:0.5f}'.format(i))
# Out:
# 0.15669
# 0.06040
# 0.04345
# 0.04095
# 0.03778
# 0.03566
# 0.03541
# 0.03507
# 0.03449
# 0.03437
# 0.03373
# 0.03322
# 0.03311
# 0.03212
# 0.03124
# 0.03048
# 0.03003
# 0.02973
# 0.02847
# 0.02791
# 0.02710
# 0.02542

# %%
principal_df2
# Out:
#              0         1          2          3         4         5         6   \
# 0     -0.173550 -0.531280  -0.223442  -0.154166  0.382044 -0.463292 -0.227322
# 1     -0.127196  4.433941   0.198482  -0.765319 -0.289109 -1.116150 -0.165568
# 2     -0.113019 -0.502256  -0.070688   0.028466 -0.578638 -1.489014  0.977746
# 3     -0.457057  0.090379  -0.086674   0.024973 -0.167532  1.058568  0.246321
# 4     -0.409861 -0.147872  -0.397855  -0.044970 -0.505702  2.119551 -1.325856
# ...         ...       ...        ...        ...       ...       ...       ...
# 21688  0.342318 -1.084908 -10.127327  13.292037  1.357699  1.214298  0.128663
# 21689 -0.025181 -0.238743  -0.373793  -0.353012 -0.348734 -1.337261 -0.155653
# 21690 -0.503656  0.118928  -0.163391  -0.844175 -0.139893 -0.964336  0.981782
# 21691 -0.340691 -0.550163  -0.363923   0.096276 -0.443776 -0.106107 -0.369089
# 21692 -0.224554 -0.343052  -0.090868  -0.666287 -0.409957  0.625482 -0.698838
#
# ...

# %%
final_df = pd.concat([principal_df2, y_df], axis=1)
final_df
# Out:
#               0         1          2          3         4         5         6  \
# 0     -0.173550 -0.531280  -0.223442  -0.154166  0.382044 -0.463292 -0.227322
# 1     -0.127196  4.433941   0.198482  -0.765319 -0.289109 -1.116150 -0.165568
# 2     -0.113019 -0.502256  -0.070688   0.028466 -0.578638 -1.489014  0.977746
# 3     -0.457057  0.090379  -0.086674   0.024973 -0.167532  1.058568  0.246321
# 4     -0.409861 -0.147872  -0.397855  -0.044970 -0.505702  2.119551 -1.325856
# ...         ...       ...        ...        ...       ...       ...       ...
# 21688  0.342318 -1.084908 -10.127327  13.292037  1.357699  1.214298  0.128663
# 21689 -0.025181 -0.238743  -0.373793  -0.353012 -0.348734 -1.337261 -0.155653
# 21690 -0.503656  0.118928  -0.163391  -0.844175 -0.139893 -0.964336  0.981782
# 21691 -0.340691 -0.550163  -0.363923   0.096276 -0.443776 -0.106107 -0.369089
# 21692 -0.224554 -0.343052  -0.090868  -0.666287 -0.409957  0.625482 -0.698838
#
# ...

# %%
corr_df2 = principal_df2.corrwith(y_df, axis = 0)
corr_df2
# Out:
# 0     0.758178
# 1    -0.008327
# 2    -0.119302
# 3    -0.035946
# 4    -0.038487
# 5    -0.058920
# 6    -0.018560
# 7     0.033529
# 8     0.027078
# 9    -0.004880
# 10   -0.007734
# 11   -0.019116
# 12    0.043401
# 13    0.030013
# 14    0.052120
# 15    0.037663
# 16    0.090958
# 17    0.019325
# 18    0.023753
# 19   -0.021074
# 20   -0.034448
# 21   -0.051868
# dtype: float64

# %%
corr_df2 = principal_df2.corrwith(y_df, axis = 0)
corr_df2 = corr_df2.to_frame()
corr_df2.columns = ['correlation']
corr_df2
# Out:
#     correlation
# 0      0.758178
# 1     -0.008327
# 2     -0.119302
# 3     -0.035946
# 4     -0.038487
# 5     -0.058920
# 6     -0.018560
# 7      0.033529
# 8      0.027078
# 9     -0.004880
# 10    -0.007734
# 11    -0.019116
# 12     0.043401
# 13     0.030013
# 14     0.052120
# 15     0.037663
# 16     0.090958
# 17     0.019325
# 18     0.023753
# 19    -0.021074
# 20    -0.034448
# 21    -0.051868

# %%
sorted_df2 = corr_df2.reindex(corr_df2.correlation.abs().sort_values().index)
sorted_df2
# Out:
#     correlation
# 9     -0.004880
# 10    -0.007734
# 1     -0.008327
# 6     -0.018560
# 11    -0.019116
# 17     0.019325
# 19    -0.021074
# 18     0.023753
# 8      0.027078
# 13     0.030013
# 7      0.033529
# 20    -0.034448
# 3     -0.035946
# 15     0.037663
# 4     -0.038487
# 12     0.043401
# 21    -0.051868
# 14     0.052120
# 5     -0.058920
# 16     0.090958
# 2     -0.119302
# 0      0.758178

# %%
max(sorted_df2['correlation'])
# Out:
# 0.7581780408430425

# %%
print("correlation 1 : ", max(sorted_df['correlation']))
print("correlation 2 : ", max(sorted_df2['correlation']))
# Out:
# correlation 1 :  0.4155759499905006
# correlation 2 :  0.7581780408430425

# %% [markdown]
# ### In contrast to the previous analysis with higher number of features wituout using PCA (as previous was done to only get the optimal number of features), we get get higer correlation after performing PCA with less number of features (when chosen only the optimal ones).

# %% [markdown]
# ### Therefore we can say that, PCA helps by doing dimesionality reduction and getting higher correlation
